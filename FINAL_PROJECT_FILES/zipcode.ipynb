# %%
# Dependencies and Setup
import pandas as pd
import time
from us import states

# %%
# Dependencies
import numpy as np
import matplotlib.pyplot as plt
import requests
from census import Census
import gmaps

# Census & gmaps API Keys
from config import (census_key, gkey)
c = Census(census_key, year=2016)

# Configure gmaps
gmaps.configure(api_key=gkey)

# %%
# Converting CSV to DataFrame
file="Resources/Hospitalv2.csv"
hospital=pd.read_csv(file, converters={"ZIP Code": str, "Provider ID": str}) #contain hospital ID, name, and address
# converters= imports a specific column into a data type, in this case keep leading 0's for zip code

# %%
# to view zip code if kept leading zeros
# hospital["ZIP Code"].sort_values(ascending=True)
hospital.columns
# Out:
# Index(['Provider ID', 'Hospital Name', 'Address', 'City', 'State', 'ZIP Code',
#        'County Name', 'Phone Number', 'HCAHPS Measure ID', 'HCAHPS Question',
#        'HCAHPS Answer Description', 'Patient Survey Star Rating',
#        'Patient Survey Star Rating Footnote', 'HCAHPS Answer Percent',
#        'HCAHPS Answer Percent Footnote', 'HCAHPS Linear Mean Value',
#        'Number of Completed Surveys', 'Number of Completed Surveys Footnote',
#        'Survey Response Rate Percent', 'Survey Response Rate Percent Footnote',
#        'Measure Start Date', 'Measure End Date'],
#       dtype='object')

# %%
hospital_df=hospital[["Provider ID", "Hospital Name", "Address", "City", "State", "ZIP Code", "County Name"]]
hospital_df.head()
# Out:
#   Provider ID                     Hospital Name                 Address  \
# 0      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 1      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 2      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 3      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
# 4      010001  SOUTHEAST ALABAMA MEDICAL CENTER  1108 ROSS CLARK CIRCLE
#
#      City State ZIP Code County Name
# 0  DOTHAN    AL    36301     HOUSTON
# 1  DOTHAN    AL    36301     HOUSTON
# 2  DOTHAN    AL    36301     HOUSTON
# 3  DOTHAN    AL    36301     HOUSTON
# 4  DOTHAN    AL    36301     HOUSTON

# %%
file1="Resources/zip_data_actual.csv"
# convert to pd DataFrame, convert column zip code from int to str
lat_lng=pd.read_csv(file1, converters={"ZIP Code": str})
lat_lng=lat_lng.drop(columns="Unnamed: 0")
lat_lng.head()
# Out:
#   ZIP Code   latitude  longitude        city state     county
# 0    00501  40.922326 -72.637078  Holtsville    NY    Suffolk
# 1    00544  40.922326 -72.637078  Holtsville    NY    Suffolk
# 2    00601  18.165273 -66.722583    Adjuntas    PR   Adjuntas
# 3    00602  18.393103 -67.180953      Aguada    PR     Aguada
# 4    00603  18.455913 -67.145780   Aguadilla    PR  Aguadilla

# %%
# check duplicates
# hospital_df["is_duplicate"]= hospital_df.duplicated()
# Provider_ID has duplicates, drop duplicate rows
hospital_df=hospital_df.drop_duplicates(["Provider ID"], keep="first")
hospital_df
# Out:
#        Provider ID                                      Hospital Name  \
# 0           010001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 50          010005                      MARSHALL MEDICAL CENTER SOUTH
# 100         010006                     ELIZA COFFEE MEMORIAL HOSPITAL
# 150         010007                           MIZELL MEMORIAL HOSPITAL
# 200         010008                        CRENSHAW COMMUNITY HOSPITAL
# 250         010011                                  ST VINCENT'S EAST
# 300         010012                     DEKALB REGIONAL MEDICAL CENTER
# 350         010016                      SHELBY BAPTIST MEDICAL CENTER
# 400         010018                              CALLAHAN EYE HOSPITAL
# 450         010019                     HELEN KELLER MEMORIAL HOSPITAL
# 246350      53004F                         CHEYENNE VA MEDICAL CENTER
# 246400      53005F                         SHERIDAN VA MEDICAL CENTER
#
#                                          Address                  City State  \
# 0                         1108 ROSS CLARK CIRCLE                DOTHAN    AL
# 50                    2505 U S HIGHWAY 431 NORTH                  BOAZ    AL
# 100                           205 MARENGO STREET              FLORENCE    AL
# 150                                702 N MAIN ST                   OPP    AL
# 200                          101 HOSPITAL CIRCLE               LUVERNE    AL
# 250                   50 MEDICAL PARK EAST DRIVE            BIRMINGHAM    AL
# 300                         200 MED CENTER DRIVE            FORT PAYNE    AL
# 350                      1000 FIRST STREET NORTH             ALABASTER    AL
# 400                         1720 UNIVERSITY BLVD            BIRMINGHAM    AL
# 450                 1300 SOUTH MONTGOMERY AVENUE             SHEFFIELD    AL
# 500                             126 HOSPITAL AVE                 OZARK    AL
# 550                             400 NORTHWOOD DR                CENTRE    AL
# 600                    2105 EAST SOUTH BOULEVARD            MONTGOMERY    AL
# 650                             1725 PINE STREET            MONTGOMERY    AL
# 700                       2000 PEPPERELL PARKWAY               OPELIKA    AL
# 750                       1032 MAIN STREET SOUTH               WEDOWEE    AL
# 800                        619 SOUTH 19TH STREET            BIRMINGHAM    AL
# 850                          805 FRIENDSHIP ROAD             TALLASSEE    AL
# 900                     1912 ALABAMA HIGHWAY 157               CULLMAN    AL
# 950                 849 SOUTH THREE NOTCH STREET             ANDALUSIA    AL
# 1000                            301 EAST 18TH ST              ANNISTON    AL
# 1050                               101 SIVLEY RD            HUNTSVILLE    AL
# 1100                        1007 GOODYEAR AVENUE               GADSDEN    AL
# 1150                  1256 MILITARY STREET SOUTH              HAMILTON    AL
# 1200                    1653 TEMPLE AVENUE NORTH               FAYETTE    AL
# 1250                      600 SOUTH THIRD STREET               GADSDEN    AL
# 1300                        515 N MIRANDA AVENUE             GEORGIANA    AL
# 1350                        400 N EDWARDS STREET            ENTERPRISE    AL
# 1400                           509 WILSON AVENUE                 EUTAW    AL
# 1450                          201 MARIARDEN ROAD             DADEVILLE    AL
# ...                                          ...                   ...   ...
# 244950                   6439 GARNERS FERRY ROAD              COLUMBIA    SC
# 245000                            109 BEE STREET            CHARLESTON    SC
# 245050                         113 COMANCHE ROAD            FORT MEADE    SD
# 245100                      500 NORTH 5TH STREET           HOT SPRINGS    SD
# 245150                     2501 WEST 22ND STREET           SIOUX FALLS    SD
# 245200                     1030 JEFFERSON AVENUE               MEMPHIS    TN
# 245250  CORNER OF LAMONT STREET AND VETERANS WAY         MOUNTAIN HOME    TN
# 245300                         3400 LEBANON PIKE          MURFREESBORO    TN
# 245350                    1310 24TH AVENUE SOUTH             NASHVILLE    TN
# 245400                  6010 AMARILLO BLVD. WEST              AMARILLO    TX
# 245450                    4500 S. LANCASTER ROAD                DALLAS    TX
# 245500                       2002 HOLCOMBE BLVD.               HOUSTON    TX
# 245550              1901 VETERANS MEMORIAL DRIVE                TEMPLE    TX
# 245600                  7400 MERTON MINTER BLVD.           SAN ANTONIO    TX
# 245650                        500 FOOTHILL BLVD.        SALT LAKE CITY    UT
# 245700                        163 VETERANS DRIVE  WHITE RIVER JUNCTION    VT
# 245750                    100 EMANCIPATION DRIVE               HAMPTON    VA
# 245800                 1201 BROAD ROCK BOULEVARD              RICHMOND    VA
# 245850                    1970 ROANOKE BOULEVARD                 SALEM    VA
# 245900                   4815 N. ASSEMBLY STREET               SPOKANE    WA
# 245950                     1660 S. COLUMBIAN WAY               SEATTLE    WA
# 246000                       200 VETERANS AVENUE               BECKLEY    WV
# 246050                    1 MEDICAL CENTER DRIVE            CLARKSBURG    WV
# 246100                   1540 SPRING VALLEY ROAD            HUNTINGTON    WV
# 246150                           510 BUTLER AVE.           MARTINSBURG    WV
# 246200                  500 EAST VETERANS STREET                 TOMAH    WI
# 246250                   5000 W. NATIONAL AVENUE             MILWAUKEE    WI
# 246300                     2500 OVERLOOK TERRACE               MADISON    WI
# 246350                    2360 E. PERSHING BLVD.              CHEYENNE    WY
# 246400                            1898 FORT ROAD              SHERIDAN    WY
#
#        ZIP Code    County Name
# 0         36301        HOUSTON
# 50        35957       MARSHALL
# 100       35631     LAUDERDALE
# 150       36467      COVINGTON
# 200       36049       CRENSHAW
# 250       35235      JEFFERSON
# 300       35968        DE KALB
# 350       35007         SHELBY
# 400       35233      JEFFERSON
# 450       35660        COLBERT
# 500       36360           DALE
# 550       35960       CHEROKEE
# 600       36116     MONTGOMERY
# 650       36106     MONTGOMERY
# 700       36801            LEE
# 750       36278       RANDOLPH
# 800       35233      JEFFERSON
# 850       36078         ELMORE
# 900       35058        CULLMAN
# 950       36420      COVINGTON
# 1000      36201        CALHOUN
# 1050      35801        MADISON
# 1100      35903         ETOWAH
# 1150      35570         MARION
# 1200      35555        FAYETTE
# 1250      35901         ETOWAH
# 1300      36033         BUTLER
# 1350      36330         COFFEE
# 1400      35462         GREENE
# 1450      36853     TALLAPOOSA
# ...         ...            ...
# 244950    29209       RICHLAND
# 245000    29401     CHARLESTON
# 245050    57741          MEADE
# 245100    57747     FALL RIVER
# 245150    57117      MINNEHAHA
# 245200    38104         SHELBY
# 245250    37684     WASHINGTON
# 245300    37129     RUTHERFORD
# 245350    37212       DAVIDSON
# 245400    79106         POTTER
# 245450    75216         DALLAS
# 245500    77030         HARRIS
# 245550    76504           BELL
# 245600    78229          BEXAR
# 245650    84148      SALT LAKE
# 245700    05009        WINDSOR
# 245750    23667   HAMPTON CITY
# 245800    23249  RICHMOND CITY
# 245850    24153     SALEM CITY
# 245900    99205        SPOKANE
# 245950    98108           KING
# 246000    25801        RALEIGH
# 246050    26301       HARRISON
# 246100    25704          WAYNE
# 246150    25405       BERKELEY
# 246200    54660         MONROE
# 246250    53295      MILWAUKEE
# 246300    53705           DANE
# 246350    82001        LARAMIE
# 246400    82801       SHERIDAN
#
# [4929 rows x 7 columns]

# %%
# hospital_df has all the hospital information
# lat_lng has all the lat and lng info for each ZIP Code
# want to merge and add lat and lng information into hospital_df, primary key ZIP Code
# when one df has duplicate rows
results=pd.merge(hospital_df, lat_lng)[["Provider ID", "Hospital Name", "Address", "City", "State", "ZIP Code",
                                        "County Name", "latitude", "longitude"]]

# %%
# check to see duplicate ZIP Codes has the correct latitude and longitude
#results[["ZIP Code","latitude","longitude"]].sort_values(by="ZIP Code", ascending=True)

# %%
# Run Census Search to retrieve data on all zip codes (2013 ACS5 Census)
# See: https://github.com/CommerceDataService/census-wrapper for library documentation
# See: https://gist.github.com/afhaque/60558290d6efd892351c4b64e5c01e9
# 0             1462.0      8.391207
# 1             8351.0     27.864531
# 2               54.0      0.478045
# 3              230.0      4.399388
# 4             1410.0      9.470715
# 5               49.0      4.103853
# 6              105.0     44.303797
# 7               95.0      2.555137
# 8              110.0      7.222587
# 9               60.0     11.363636
# 10            4233.0     18.450072
# 11            3166.0     10.336609
# 12             644.0     25.474684
# 13              45.0      4.420432
# 14            1774.0      9.926141
# 15             677.0      4.214655
# 16              96.0     12.631579
# 17            1124.0      9.966306
# 18             268.0     22.483221
# 19              15.0      2.542373
# 20             290.0      4.595880
# 21             230.0      9.900990
# 22             384.0      7.193706
# 23             256.0      4.932563
# 24              86.0     11.390728
# 25             157.0      5.502979
# 26              78.0      6.532663
# 27           11227.0     27.872393
# 28             221.0      9.432352
# 29             251.0     14.790807
# ...              ...           ...
# 33088         6773.0     41.298780
# 33089         5796.0     32.976787
# 33090        16497.0     45.692998
# 33091        14130.0     54.884444
# 33092        25640.0     47.427028
# 33093         4090.0     59.069902
# 33094        30283.0     29.883458
# 33095         3816.0     26.818469
# 33096            0.0      0.000000
# 33097            0.0      0.000000
# 33098        27562.0     35.583155
# 33101         3837.0     42.267019
# 33102        22188.0     30.514908
# 33103        27492.0     38.395576
# 33104        15785.0     37.445143
# 33105        14437.0     29.859976
# 33106           18.0      0.741046
# 33107         8895.0     29.016474
# 33108        11245.0     54.829587
# 33109         3923.0     52.008485
# 33110         2893.0     18.102747
# 33111          354.0     10.750076
# 33112         7532.0     17.366043
# 33113        11107.0     38.903678
# 33114        18363.0     30.061882
# 33115         2613.0     17.397963
# 33116         5189.0     34.886379
# 33117        12301.0     31.923287
# 33118        11302.0     33.919568
# 33119        15396.0     26.226045
#
# [32515 rows x 7 columns]

# %%
# results is list of hospital and some hospitals are in the same zip code. 
# will want ZIP Code column to be unique and add a new column of hospital count
# check to see if there are any rows with missing data
results.count()
# Out:
# Provider ID      4890
# Hospital Name    4890
# Address          4890
# City             4890
# State            4890
# ZIP Code         4890
# County Name      4875
# latitude         4880
# longitude        4880
# dtype: int64

# %%
# drop the missing data rows
results=results.dropna(how="any")
results.count()
# Out:
# Provider ID      4865
# Hospital Name    4865
# Address          4865
# City             4865
# State            4865
# ZIP Code         4865
# County Name      4865
# latitude         4865
# longitude        4865
# dtype: int64

# %%
# get count of hospitals per zip code
hospital_counts=results["ZIP Code"].value_counts()
hospital_counts
# Out:
# 77030    7
# 48201    5
# 70508    5
# 76104    5
# 19104    5
# 75093    4
# 39301    4
# 60612    4
# 39216    4
# 72205    4
# 77479    4
# 73120    4
# 78229    4
# 63110    4
# 79902    4
# 35233    4
# 12208    3
# 99508    3
# 90033    3
# 71301    3
# 75231    3
# 93301    3
# 77598    3
# 77070    3
# 37129    3
# 46202    3
# 77090    3
# 12180    3
# 75235    3
# 25301    3
#         ..
# 92801    1
# 80229    1
# 22191    1
# 87114    1
# 46975    1
# 43078    1
# 53534    1
# 51041    1
# 85234    1
# 46360    1
# 46714    1
# 59019    1
# 26757    1
# 67455    1
# 37074    1
# 95971    1
# 56278    1
# 64085    1
# 79331    1
# 30655    1
# 04614    1
# 92869    1
# 28501    1
# 19007    1
# 75203    1
# 77964    1
# 66547    1
# 34698    1
# 00921    1
# 80210    1
# Name: ZIP Code, Length: 4420, dtype: int64

# %%
# convert it to a DataFrame
hospital_count_zip=pd.DataFrame(hospital_counts)
hospital_count_zip
# Out:
#        ZIP Code
# 77030         7
# 48201         5
# 70508         5
# 76104         5
# 19104         5
# 75093         4
# 39301         4
# 60612         4
# 39216         4
# 72205         4
# 77479         4
# 73120         4
# 78229         4
# 63110         4
# 79902         4
# 35233         4
# 12208         3
# 99508         3
# 90033         3
# 71301         3
# 75231         3
# 93301         3
# 77598         3
# 77070         3
# 37129         3
# 46202         3
# 77090         3
# 12180         3
# 75235         3
# 25301         3
# ...         ...
# 92801         1
# 80229         1
# 22191         1
# 87114         1
# 46975         1
# 43078         1
# 53534         1
# 51041         1
# 85234         1
# 46360         1
# 46714         1
# 59019         1
# 26757         1
# 67455         1
# 37074         1
# 95971         1
# 56278         1
# 64085         1
# 79331         1
# 30655         1
# 04614         1
# 92869         1
# 28501         1
# 19007         1
# 75203         1
# 77964         1
# 66547         1
# 34698         1
# 00921         1
# 80210         1
#
# [4420 rows x 1 columns]

# %%
# rename the column to Hospital Count
hospital_count_zip=hospital_count_zip.rename(columns={"ZIP Code":"Hospital Count"})
hospital_count_zip
# Out:
#        Hospital Count
# 77030               7
# 48201               5
# 70508               5
# 76104               5
# 19104               5
# 75093               4
# 39301               4
# 60612               4
# 39216               4
# 72205               4
# 77479               4
# 73120               4
# 78229               4
# 63110               4
# 79902               4
# 35233               4
# 12208               3
# 99508               3
# 90033               3
# 71301               3
# 75231               3
# 93301               3
# 77598               3
# 77070               3
# 37129               3
# 46202               3
# 77090               3
# 12180               3
# 75235               3
# 25301               3
# ...               ...
# 92801               1
# 80229               1
# 22191               1
# 87114               1
# 46975               1
# 43078               1
# 53534               1
# 51041               1
# 85234               1
# 46360               1
# 46714               1
# 59019               1
# 26757               1
# 67455               1
# 37074               1
# 95971               1
# 56278               1
# 64085               1
# 79331               1
# 30655               1
# 04614               1
# 92869               1
# 28501               1
# 19007               1
# 75203               1
# 77964               1
# 66547               1
# 34698               1
# 00921               1
# 80210               1
#
# [4420 rows x 1 columns]

# %%
# reset the index, so that zip code is a column and rename the column to ZIP Code
hospital_count_zip=hospital_count_zip.reset_index()
hospital_count_zip=hospital_count_zip.rename(columns={"index":"ZIP Code"})
hospital_count_zip
# Out:
#      ZIP Code  Hospital Count
# 0       77030               7
# 1       48201               5
# 2       70508               5
# 3       76104               5
# 4       19104               5
# 5       75093               4
# 6       39301               4
# 7       60612               4
# 8       39216               4
# 9       72205               4
# 10      77479               4
# 11      73120               4
# 12      78229               4
# 13      63110               4
# 14      79902               4
# 15      35233               4
# 16      12208               3
# 17      99508               3
# 18      90033               3
# 19      71301               3
# 20      75231               3
# 21      93301               3
# 22      77598               3
# 23      77070               3
# 24      37129               3
# 25      46202               3
# 26      77090               3
# 27      12180               3
# 28      75235               3
# 29      25301               3
# ...       ...             ...
# 4390    92801               1
# 4391    80229               1
# 4392    22191               1
# 4393    87114               1
# 4394    46975               1
           edgecolor="black", linewidths=1, marker="o",
           alpha=0.8, label="ZIP Code")
# graph properties
plt.title("Population vs. Hospital Count by Zip Code")
plt.xlabel("Hospital Count")
plt.ylabel("Population")
plt.grid(True)

# save figure
plt.savefig("output/population_hospital_count.png")

# show plot
plt.show()

# %%
# build scatter plot
plt.scatter(hospital_count_by_zipcode["Hospital Count"], hospital_count_by_zipcode["Median Age"],
           edgecolor="black", linewidths=1, marker="o",
           alpha=0.8, label="ZIP Code")
# graph properties
plt.title("Median Age vs. Hospital Count by Zip Code")
plt.xlabel("Hospital Count")
plt.ylabel("Median Age")
plt.grid(True)

# save figure
plt.savefig("output/median_age_hospital_count.png")

# show plot
plt.show()

# %%
# build scatter plot
plt.scatter(hospital_count_by_zipcode["Hospital Count"], hospital_count_by_zipcode["Household Income"],
           edgecolor="black", linewidths=1, marker="o",
           alpha=0.8, label="ZIP Code")
# graph properties
plt.title("Household Income vs. Hospital Count by Zip Code")
plt.xlabel("Hospital Count")
plt.ylabel("Household Income")
plt.grid(True)
plt.ylim(0,200000)

# save figure
plt.savefig("output/household_income_hospital_count.png")

# show plot
plt.show()

# %%
# build scatter plot
plt.scatter(hospital_count_by_zipcode["Hospital Count"], hospital_count_by_zipcode["Per Capita Income"],
           edgecolor="black", linewidths=1, marker="o",
           alpha=0.8, label="ZIP Code")
# graph properties
plt.title("Per Capita Income vs. Hospital Count by Zip Code")
plt.xlabel("Hospital Count")
plt.ylabel("Per Capita Income")
plt.grid(True)

# save figure
plt.savefig("output/percapita_hospital_count.png")

# show plot
plt.show()

# %%
# build scatter plot
plt.scatter(hospital_count_by_zipcode["Hospital Count"], hospital_count_by_zipcode["Poverty Rate"],
           edgecolor="black", linewidths=1, marker="o",
           alpha=0.8, label="ZIP Code")
# graph properties
plt.title("Poverty Rate vs. Hospital Count by Zip Code")
plt.xlabel("Hospital Count")
plt.ylabel("Poverty Rate")
plt.grid(True)

# save figure
plt.savefig("output/poverty_rate_hospital_count.png")

# show plot
plt.show()

# %%
# heatmap of poverty rate
# configure gmaps with API key
gmaps.configure(api_key=gkey)

# %%
hospital_heatmap=pd.merge(hospital_count_by_zipcode, lat_lng, on="ZIP Code")
hospital_heatmap
# Out:
#      ZIP Code  Population  Median Age  Household Income  Per Capita Income  \
# 0       01040     40280.0        34.4           38829.0            21897.0
# 1       01053      1697.0        49.8           66528.0            30391.0
# 2       01060     15407.0        35.0           56128.0            35487.0
# 3       01069      8753.0        44.0           57994.0            30199.0
# 4       01085     41479.0        39.0           63283.0            29597.0
# 5       01104     23183.0        35.2           28590.0            18983.0
# 6       01201     45001.0        43.4           45893.0            28433.0
# 7       01230      8195.0        49.4           59702.0            35371.0
# 8       01301     17730.0        42.6           49024.0            28633.0
# 9       01331     13205.0        43.9           51750.0            25349.0
# 10      01432      7594.0        38.8           77462.0            42565.0
# 11      01440     20334.0        39.8           46410.0            24680.0
# 12      01453     41336.0        40.8           56577.0            29527.0
# 13      01510     13759.0        39.3           60755.0            30955.0
# 14      01550     16824.0        38.5           48762.0            24724.0
# 15      01605     28696.0        31.3           35446.0            20729.0
# 16      01608      3511.0        27.5           18843.0            12874.0
# 17      01701     32061.0        44.7          100788.0            47041.0
# 15           7360.0     25.648174               1  42.288792 -71.796128
# 16           1764.0     50.242096               1  42.293501 -71.925696
# 17           1442.0      4.497676               1  42.446396 -71.459405
# 18            385.0      2.746469               1  42.446396 -71.459405
# 19            919.0      4.725422               1  42.446396 -71.459405
# 20           2830.0      7.156404               1  42.446396 -71.459405
# 21           2167.0      7.576923               1  42.147087 -71.528085
# 22           1330.0      5.175500               1  42.504844 -71.201539
# 23           4996.0     10.184072               1  42.731840 -71.186915
# 24           6319.0     21.637447               1  42.446396 -71.459405
# 25            529.0      2.352052               1  42.454545 -71.148779
# 26           2946.0      7.191154               1  42.565145 -70.853843
# 27           1367.0      7.663845               1  42.809650 -70.873196
# 28           6227.0     14.600234               1  42.512946 -70.904237
# 29           2334.0      8.043283               1  42.182798 -71.196277
# ...             ...           ...             ...        ...        ...
# 4212        25331.0     49.124406               1  18.455913 -67.145780
# 4213         1131.0     66.962700               1  18.269187 -66.864993
# 4214        14982.0     51.796024               1  18.250027 -66.698957
# 4215        19077.0     45.918883               2  18.445530 -66.490268
# 4216        21641.0     56.227915               1  18.383727 -67.080799
# 4217        17138.0     52.841242               1  18.219023 -67.508068
# 4218        15961.0     49.787884               2  18.113284 -67.039706
# 4219        26396.0     45.963641               1  18.443109 -66.398302
# 4220        19116.0     49.649369               1  18.061040 -66.861164
# 4221        11623.0     47.660639               1  18.128092 -66.268717
# 4222        10567.0     58.842856               1  18.001995 -66.607429
# 4223        34917.0     41.827286               2  18.212965 -66.058033
# 4224        13975.0     43.120738               2  18.359381 -65.611361
# 4225         4518.0     38.958351               1  18.001995 -66.607429
# 4226        22607.0     44.753044               2  18.138029 -65.788499
# 4227         4561.0     26.104625               1  18.451647 -66.077003
# 4228         2985.0     53.658098               1  18.443384 -66.068133
# 4229         2289.0     39.753387               1  18.444187 -66.059859
# 4230        16920.0     60.057502               1  18.437896 -66.048087
# 4231         6773.0     41.298780               1  18.419069 -66.062319
# 4232        16497.0     45.692998               1  18.390429 -66.066124
# 4233        14130.0     54.884444               1  18.410775 -66.036708
# 4234         3816.0     26.818469               1  18.385174 -66.071959
# 4235            0.0      0.000000               3  18.410462 -66.060533
# 4236        27492.0     38.395576               1  18.326702 -66.174176
# 4237        14437.0     29.859976               1  18.387058 -66.159044
# 4238           18.0      0.741046               1  18.344870 -66.166014
# 4239         8895.0     29.016474               1  18.413195 -66.168651
# 4240         7532.0     17.366043               1  18.362322 -66.113729
# 4241         2613.0     17.397963               1  18.410462 -66.060533
#
#                   city state      county
# 0              Holyoke    MA     Hampden
# 1                Leeds    MA   Hampshire
# 2          Northampton    MA   Hampshire
# 3               Palmer    MA     Hampden
# 4            Westfield    MA     Hampden
# 5          Springfield    MA     Hampden
# 6           Pittsfield    MA   Berkshire
# 7     Great Barrington    MA   Berkshire
# 8           Greenfield    MA    Franklin
# 9                Athol    MA   Worcester
# 10                Ayer    MA   Middlesex
# 11             Gardner    MA   Worcester
# 12          Leominster    MA   Worcester
# 13             Clinton    MA   Worcester
# 14         Southbridge    MA   Worcester
# 15           Worcester    MA   Worcester
# 16           Worcester    MA   Worcester
# 17          Framingham    MA   Middlesex
# 18             Bedford    MA   Middlesex
# 19             Concord    MA   Middlesex
# 20         Marlborough    MA   Middlesex
# 21             Milford    MA   Worcester
# 22          Burlington    MA   Middlesex
# 23             Methuen    MA       Essex
# 24              Lowell    MA   Middlesex
# 25          Winchester    MA   Middlesex
# 26             Beverly    MA       Essex
# 27         Newburyport    MA       Essex
# 28               Salem    MA       Essex
# 29             Norwood    MA     Norfolk
# ...                ...   ...         ...
# 4212         Aguadilla    PR   Aguadilla
# 4213          Castaner    PR       Lares
# 4214            Utuado    PR      Utuado
# 4215            Manati    PR      Manati
# 4216              Moca    PR        Moca
# 4217          Mayaguez    PR    Mayaguez
# 4218        San German    PR  San German
# 4219         Vega Baja    PR   Vega Baja
# 4220             Yauco    PR       Yauco
# 4221          Aibonito    PR    Aibonito
# 4222             Ponce    PR       Ponce
# 4223            Caguas    PR      Caguas
# 4224           Fajardo    PR     Fajardo
# 4225       Coto Laurel    PR       Ponce
# 4226           Humacao    PR     Humacao
# 4227          San Juan    PR    San Juan
# 4228          San Juan    PR    San Juan
# 4229          San Juan    PR    San Juan
# 4230          San Juan    PR    San Juan
# 4231          San Juan    PR    San Juan
# 4232          San Juan    PR    San Juan
# 4233          San Juan    PR    San Juan
# 4234          San Juan    PR    San Juan
# 4235          San Juan    PR    San Juan
# 4236           Bayamon    PR     Bayamon
# 4237           Bayamon    PR     Bayamon
# 4238           Bayamon    PR     Bayamon
# 4239           Bayamon    PR     Bayamon
# 4240          Guaynabo    PR    Guaynabo
# 4241          Carolina    PR    San Juan
#
# [4242 rows x 13 columns]

# %%
# pull lat and lng and poverty rate from hospital_heatmap dataframe
locations=hospital_heatmap[["latitude", "longitude"]].astype(float)
locations
print(len(locations))
poverty_rate=hospital_heatmap["Poverty Rate"].astype(float)
poverty_rate
print(len(poverty_rate))
# Out:
# 4242
# 4242

# %%
# Create a poverty Heatmap layer
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=poverty_rate, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 1)

# Adjust heat_layer setting to help with heatmap dissipating on zoom
heat_layer.dissipating = False
heat_layer.max_intensity = 100
heat_layer.point_radius = 1

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Convert hospital rate to list
hospital_rate = hospital_heatmap["Hospital Count"].tolist()

# %%
# Create hospital symbol layer
hospital_layer = gmaps.symbol_layer(
    locations, fill_color='rgba(0, 150, 0, 0.4)',
    stroke_color='rgba(0, 0, 150, 0.4)', scale=2,
    info_box_content=[f"Hospital amount: {hospital}" for hospital in hospital_rate]
)


fig = gmaps.figure()
fig.add_layer(hospital_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
median_age=hospital_heatmap["Median Age"].astype(float)
median_age
print(len(median_age))
# Out:
# 4242

# %%
# Create a poverty Heatmap layer
fig = gmaps.figure()

heat_layer2 = gmaps.heatmap_layer(locations, weights=median_age, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 1)

# Adjust heat_layer setting to help with heatmap dissipating on zoom
heat_layer2.dissipating = False
heat_layer2.max_intensity = 100
heat_layer2.point_radius = 1

fig.add_layer(heat_layer2)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Create a combined map poverty rate
fig = gmaps.figure()

fig.add_layer(heat_layer)
fig.add_layer(hospital_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# Create a combined map median age
fig = gmaps.figure()

fig.add_layer(heat_layer2)
fig.add_layer(hospital_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
